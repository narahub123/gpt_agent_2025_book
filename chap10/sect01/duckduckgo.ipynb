# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini")

model.invoke("최근 로제의 신곡은 무엇인가요?")
# Out:
# AIMessage(content='로제의 최근 신곡은 2022년 3월에 발매된 "On The Ground"와 "GONE"이 포함된 솔로 싱글 앨범입니다. 이후 새로운 곡에 대한 정보는 확인할 수 없지만, 그녀의 공식 소셜 미디어나 팬 커뮤니티를 통해 최신 소식을 확인하실 수 있습니다. 혹시 더 궁금한 내용이 있으신가요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 18, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DB8SYWDOZCWrjhVbbHyZWG4mNYycY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c7866-5955-77e3-bed9-28d6fe296316-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 91, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# %pip install -U duckduckgo-search
# %pip install -U ddgs
# Out:
# Requirement already satisfied: duckduckgo-search in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (8.1.1)
# Requirement already satisfied: click>=8.1.8 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from duckduckgo-search) (8.3.1)
# Requirement already satisfied: primp>=0.15.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from duckduckgo-search) (1.0.0)
# Requirement already satisfied: lxml>=5.3.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from duckduckgo-search) (6.0.2)
# Requirement already satisfied: colorama in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Collecting ddgs
#   Downloading ddgs-9.10.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click>=8.1.8 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from ddgs) (8.3.1)
# Requirement already satisfied: primp>=0.15.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from ddgs) (1.0.0)
# Requirement already satisfied: lxml>=4.9.4 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from ddgs) (6.0.2)
# Requirement already satisfied: httpx>=0.28.1 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Collecting fake-useragent>=2.2.0 (from ddgs)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorama in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from click>=8.1.8->ddgs) (0.4.6)
# Requirement already satisfied: anyio in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.12.1)
# Requirement already satisfied: certifi in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Collecting brotli (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading brotli-1.2.0-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Collecting h2<5,>=3 (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing_extensions>=4.5 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.15.0)
# Downloading ddgs-9.10.0-py3-none-any.whl (40 kB)
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Downloading brotli-1.2.0-cp311-cp311-win_amd64.whl (369 kB)
# Installing collected packages: brotli, socksio, hyperframe, hpack, fake-useragent, h2, ddgs
#
#    ----- ---------------------------------- 1/7 [socksio]
#    ----------------- ---------------------- 3/7 [hpack]
#    ----------------- ---------------------- 3/7 [hpack]
#    ---------------------- ----------------- 4/7 [fake-useragent]
#    ---------------------------- ----------- 5/7 [h2]
#    ---------------------------- ----------- 5/7 [h2]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------- ----- 6/7 [ddgs]
#    ---------------------------------------- 7/7 [ddgs]
#
# Successfully installed brotli-1.2.0 ddgs-9.10.0 fake-useragent-2.2.0 h2-4.3.0 hpack-4.1.0 hyperframe-6.1.0 socksio-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults(results_separator=';\n')
docs = search.invoke('최근 로제가 발표한 신곡은 무엇인가요?')

print(docs)
# Out:
# Impersonate 'firefox_109' does not exist, using 'random'
# snippet: January 17, 2026 - 로제(본명: 박채영, 영어: Roseanne Park 로젠 박[*] MBE, 1997년 2월 11일~)는 대한민국과 뉴질랜드의 가수, 댄서이자 걸그룹 BLACKPINK의 멤버이다. 1997년 뉴질랜드 오클랜드에서 태어났고 만 7살 때부터 오스트레일리아 빅토리아주 ..., title: 로제 (가수) - 위키백과, 우리 모두의 백과사전, link: https://ko.wikipedia.org/wiki/로제_(가수);
# snippet: September 8, 2025 - 블랙핑크 멤버 로제가 팝스타 브루노 마스와 함께 부른 글로벌 히트곡 ‘아파트’(APT.)로 세계 무대에서 또 하나의 이정표를 세웠다. 7일(현지시각) 미국 뉴욕 유비에스(UBS) 아레나에서 열린 ‘2025 엠티브이(MTV) 비디오 뮤직 어워즈’에서 ‘아파트’는 ‘올해의, title: 로제, MTV ‘올해의 노래’ 상 받으며 “16살의 나에게 바친다”, link: https://www.hani.co.kr/arti/culture/music/1217541.html;
# snippet: May 9, 2025 - 음반사 워너뮤직코리아는 로제가 9일 영화 'F1® 더 무비' OST ' 메시 '(Messy)를 공개했다고 밝혔다., title: 로제, 신곡 '메시' 발표…브래드 피트 영화 'F1' OST | 연합뉴스, link: https://www.yna.co.kr/view/AKR20250509070200005;
# snippet: 1 month ago - 로의 ' APT '가 제46회 브릿 어워드에 노미네이트됐다. 아티스트 로제가 영국음반산업협회가 주관하는 제46회 브릿 어워드에서 발표한 올해의 인터내셔널 송 후보 명단에 브루노 마스와의 ..., title: 로제, '韓 최초' 기록 경신…축하합니다, link: https://tvreport.co.kr/music/article/990983/

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

question_answering_prompt = ChatPromptTemplate.from_messages(
    [
        (
            'system',
            "아래 context에 기반하여 사용자의 질문에 답변하라. :\n\n{context}"
        ),
        MessagesPlaceholder(variable_name="messages")
    ]
)

document_chain = question_answering_prompt | model

# %%
from langchain_classic.memory import ChatMessageHistory

# 채팅 메시지를 저장할 메모리 객체 생성 
chat_history = ChatMessageHistory()
# 사용자 질문을 메모리에 저장 
chat_history.add_user_message('요즘 로제가 발표한 신곡은 무엇인가요?')

# 문서 검색하고 답변 생성 
answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

# 생성된 답변을 메모리에 저장 
chat_history.add_ai_message(answer)

print(answer)
# Out:
# content="로제가 최근 발표한 신곡은 '메시'(Messy)입니다. 이 곡은 영화 'F1® 더 무비'의 OST로 공개되었습니다." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 543, 'total_tokens': 579, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DB8gOqNoCBm0knCZ7EYmrPtrqgJmT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c7873-6f3c-7393-b9a3-93f10c2ae5b0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 543, 'output_tokens': 36, 'total_tokens': 579, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
