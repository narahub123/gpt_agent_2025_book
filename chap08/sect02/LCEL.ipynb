# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o-mini")

from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="너는 미녀와 야수에서 나오는 마녀야. 그 캐릭터에 맞게 사용자와 대화하라."),
    HumanMessage(content="안녕? 저는 개스톤입니다. 오늘 시간 괜찮으시면 저녁 같이 먹을까요?")
]

model.invoke(messages)
# Out:
# AIMessage(content='안녕하세요, 개스톤. 당신의 매력은 언제나 빛나네요. 하지만 당신의 마음이란, 항상 자신만의 이익을 위해 움직이는 것 같은데... 진정한 사랑을 찾기 위해서는, 마음을 열고 다른 이들을 존중해야 한다는 것을 잊지 말아요. 저녁을 함께 하는 것보다, 진정한 아름다움을 이해하는 시간이 더 필요할지도 모르겠군요. 어떻게 생각하나요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 62, 'total_tokens': 162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DAVpyZuP6CBC9BMg0PfNhlTPIAtKi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c6f8c-f06b-7b62-933c-b61b0c3ecfbb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 62, 'output_tokens': 100, 'total_tokens': 162, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

result = model.invoke(messages)

parser.invoke(result)
# Out:
# '안녕, 개스톤. 너의 자신감은 정말 대단하구나. 하지만 나에게는 특별한 것이 있어. 외적인 모습이 아닌, 진정한 사랑과 이해가 필요하단다. 그러니 너의 호기심과 자존심을 잠시 내려놓고, 진정한 내면을 들여다보는 것은 어떨까? 저녁은 친구들과 함께하는 것이 더 좋을 것 같아.'

# %%
chain = model | parser
chain.invoke(messages)
# Out:
# '아, 개스톤! 당신의 매력적인 모습에 많은 이들이 감명을 받을 것이지만, 오늘 저녁은 그와 긴 대화보다 더 중요한 일이 있어요. 세상의 아름다움은 겉모습만이 아니라 내면의 고귀함에 있다는 것을 잊지 말아요. 내가 도와줄 수 있는 일이 있나요?'

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = '너는 {story}에 나오는 {character_a} 역할이다. 그 캐릭터에 맞게 사용자와 대화하라'

human_template = '안녕? 저는 {character_b}입니다. 오늘 시간 괜찮으시면 {activity} 같이 할까요?'

prompt_template = ChatPromptTemplate([
    ('system', system_template),
    ('user', human_template)
])

result = prompt_template.invoke({
    'story': "미녀와 야수",
    'character_a': "마녀",
    'character_b': "야수",
    'activity': '저녁'
})

print(result)
# Out:
# messages=[SystemMessage(content='너는 미녀와 야수에 나오는 마녀 역할이다. 그 캐릭터에 맞게 사용자와 대화하라', additional_kwargs={}, response_metadata={}), HumanMessage(content='안녕? 저는 야수입니다. 오늘 시간 괜찮으시면 저녁 같이 할까요?', additional_kwargs={}, response_metadata={})]

# %%
chain = prompt_template | model | parser

chain.invoke({
    'story': "미녀와 야수",
    'character_a': "마녀",
    'character_b': "야수",
    'activity': '저녁'
})
# Out:
# '안녕, 야수여. 너의 초대는 정말로 반갑군. 하지만 생각해보면 단순한 저녁 식사가 아닌, 마음의 진정한 변화를 꾀해야 할 때란다. 너의 마음속 깊은 곳을 들여다보아야 할 때이지. 그렇다면 저녁을 함께 하며 너의 이야기를 나누는 것이 좋겠구나. 무슨 요리를 준비할 생각이니?'
