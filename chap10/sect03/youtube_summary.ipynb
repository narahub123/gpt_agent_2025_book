# %%
# %pip install youtube-search
# Out:
# Collecting youtube-search
#   Downloading youtube_search-2.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: requests in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from youtube-search) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from requests->youtube-search) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from requests->youtube-search) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from requests->youtube-search) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from requests->youtube-search) (2026.1.4)
# Downloading youtube_search-2.2.0-py3-none-any.whl (3.6 kB)
# Installing collected packages: youtube-search
# Successfully installed youtube-search-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from youtube_search import YoutubeSearch

videos = YoutubeSearch("인도네시아 인종차별", max_results=5).to_dict()
videos
# Out:
# [{'id': 'vP_8LacSzts',
#   'thumbnails': ['https://i.ytimg.com/vi/vP_8LacSzts/hq720_2.jpg?sqp=-oaymwE9COgCEMoBSFryq4qpAy8IARUAAAAAGAAlAADIQj0AgKJDeAHwAQH4AbYIgAKAD4oCDAgAEAEYZSBWKEgwDw==&rs=AOn4CLAqsOMa5ecp2jgSAOCTylKKQtK64Q',
#    'https://i.ytimg.com/vi/vP_8LacSzts/hq720_2.jpg?sqp=-oaymwExCNAFEJQDSFryq4qpAyMIARUAAIhCGADwAQH4AbYIgAKAD4oCDAgAEAEYZSBWKEgwDw==&rs=AOn4CLBe8li57db8nk9PCkAckI9wjMyxFg'],
#   'title': '한국인은 ‘인종차별주의자‘? 논란의 인도네시아 팬덤',
#   'long_desc': None,
#   'channel': '비사일',
#   'duration': '0:35',
#   'views': '조회수 1,482회',
#   'publish_time': '3주 전',
#   'url_suffix': '/shorts/vP_8LacSzts'},
#  {'id': 'tJssmxMOuEA',
#   'thumbnails': ['https://i.ytimg.com/vi/tJssmxMOuEA/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDd80o9cK1jwY-I8I7hUsUP6SkzyA',
#    'https://i.ytimg.com/vi/tJssmxMOuEA/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLA5qjyBXWg-LN9_b7PMuYSLLDYATA'],
#   'title': '"원숭이" 인종차별 논란…파푸아 유혈사태 격화 / 연합뉴스TV (YonhapnewsTV)',
#   'long_desc': None,
#   'channel': '연합뉴스TV',
#   'duration': '1:44',
#   'views': '조회수 808회',
#   'publish_time': '6년 전',
#   'url_suffix': '/watch?v=tJssmxMOuEA&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D'},
#  {'id': 'RyhD_2XJbPI',
#   'thumbnails': ['https://i.ytimg.com/vi/RyhD_2XJbPI/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDC_EitzBFK2qjZZYdSoxCQPqmh9Q',
#    'https://i.ytimg.com/vi/RyhD_2XJbPI/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDC0v3rfyuEaHIAStyWR4yEYaCJrA'],
#   'title': '[라디오스타] 인종차별러 참교육👊 현지 텃세 이겨낸 명예영국인의 무적 필살기, MBC 260218 방송',
#   'long_desc': None,
#   'channel': 'MBCentertainment',
#   'duration': '3:25',
#   'views': '조회수 167,180회',
#   'publish_time': '1일 전',
#   'url_suffix': '/watch?v=RyhD_2XJbPI&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D'},
#  {'id': 'eMvKaLucrkU',
#   'thumbnails': ['https://i.ytimg.com/vi/eMvKaLucrkU/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCvDlDT-BoSPpDsKpRs6Ywx_Bywqw',
#    'https://i.ytimg.com/vi/eMvKaLucrkU/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDNz3tmwOFMJqw6sRTXF1npgxitfQ'],
#   'title': "K팝 비하부터 독립운동가 조롱까지…동남아 혐한에 韓 네티즌들 '폭발'",
#   'long_desc': None,
#   'channel': '뉴스1TV',
#   'duration': '3:39',
#   'views': '조회수 850회',
#   'publish_time': '45분 전',
#   'url_suffix': '/watch?v=eMvKaLucrkU&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D'},
#  {'id': 'YI3efB1sawc',
#   'thumbnails': ['https://i.ytimg.com/vi/YI3efB1sawc/hq720.jpg?sqp=-oaymwE9COgCEMoBSFryq4qpAy8IARUAAAAAGAAlAADIQj0AgKJDeAHwAQH4AbYIgAKAD4oCDAgAEAEYciBMKEAwDw==&rs=AOn4CLCCfVDrLuFGtuQVf4m4_gQqAbeC3Q',
#    'https://i.ytimg.com/vi/YI3efB1sawc/hq720.jpg?sqp=-oaymwExCNAFEJQDSFryq4qpAyMIARUAAIhCGADwAQH4AbYIgAKAD4oCDAgAEAEYciBMKEAwDw==&rs=AOn4CLADnn2Ai0wS2pgDQAqD8yIQ8te2ag'],
#   'title': '한국인은 모르는 한국인의 인종차별',
#   'long_desc': None,
#   'channel': 'Creative Den',
#   'duration': '0:43',
#   'views': '조회수 86,915회',
#   'publish_time': '8개월 전',
#   'url_suffix': '/shorts/YI3efB1sawc'}]

# %%
video_url = 'https://youtube.com' + videos[3]['url_suffix']
video_url
# Out:
# 'https://youtube.com/watch?v=eMvKaLucrkU&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D'

# %%
# %pip install youtube_transcript_api
# Out:
# Collecting youtube_transcript_api
#   Downloading youtube_transcript_api-1.2.4-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from youtube_transcript_api) (0.7.1)
# Requirement already satisfied: requests in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from youtube_transcript_api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from requests->youtube_transcript_api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from requests->youtube_transcript_api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from requests->youtube_transcript_api) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from requests->youtube_transcript_api) (2026.1.4)
# Downloading youtube_transcript_api-1.2.4-py3-none-any.whl (485 kB)
# Installing collected packages: youtube_transcript_api
# Successfully installed youtube_transcript_api-1.2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import YoutubeLoader

loader = YoutubeLoader.from_youtube_url(
    video_url,
    language=['ko', 'en'] # 자막 언어
)

loader.load()
# Out:
# [Document(metadata={'source': 'eMvKaLucrkU'}, page_content='Oin netizen-netizen Korea tuh o. Hei dengar ya idol kalian tanpa netizen Indonesia bisa apa? Kerasa pasok inom 동남아시아 젊은 세대 사이에서 최근 사회관계망 서비스를 중심으로 혐한 정서가 고조되고 있습니다. 말레이시아와 인도네시아, 베트남, 태국, 필리핀 등 동남아 네티즌들은 21엑와 틱톡 등 소셜 미디어를 통해 한국인이 인종 차별한다는 취지에 글과 영상을 개제했는데요. 이들은 동남아의 형제 자매들이 연대한다는 뜻을 지닌 합성어 시블링이란 해시태그를 달면서 한국은 인종차별주의 국가라고 주장했습니다. 이러한 동남안의 혐한 정서는 지난달 31일 말레이시아에서 열린 한국 보이그룹 데이스 공연이 기폭제가 됐는데요. 당시 현지 임페는 공연에서 반입 금지된 대형 렌즈가 달린 카메라 즉 대포 카메라로 촬영하다 발각된 한국인 팬을 겨냥해 콘서트 관람 매너를 꼬집었다는 전원입니다. 이후 비난 여론이 들끌 대포 카메라로 촬영했던 팬이 사과를 개시했지만 동남아 네티즌들은 문제된 팬의 신상 정보 및 사진을 무단으로 퍼날랐고 한국 사회 전반 또한 비난한 것으로 알려졌는데요. 이에 한국 네티즌들은 선넘은 신상토리와 공격에 분노하면서팝 인기를 질투해 근거없는 발언을 일삼고 있다며 반격했고 한국과 동남아간 감정섞인 신랑이가 이어졌습니다. 동남아 네티즌들은 한국의 의식주 독립운동과 대형참사 희생자들을 비하하는가 하면 하얀 피부색을 선망하는 성형 괴물이 가득한 나라고 조롱했는데요. 그러면서 한국이 동남아 국가 덕분에 가난으로부터 벗어났다며 닭장 같은 아파트에서 사는 한국을 우리가 먹여 살린다고 주장해 공분을 샀습니다. 한국 네티즌들은 우리나라에서 이민자 코터로 쉽게 취업해 돈 벌어 가는 동남아인들이 혐만을 하느냐며 이게하고 교육을 못 받은 거짓대들이라고 맞불을 낳는데요. 이어 체급이 비슷해야 싸울 맛이 나는데 그곳에서 인터넷은 되느냐며 우리는 원래 피부색이 밝은 편이다. 열등감에 가득찬 동남아인들이 한국을 시샘에 사실을 왜곡하고 있다라고 덧붙였습니다. 특히 한국인의 피부색은 가짜라며 혐안을 주도하는 인도네시아에 대해선 뒤통수쳐서 떼먹은 KF21 분담금이나 가프라고 경로했는데요. 한국 네티즌들이 원숭이와 오랑오탄 등 동물 이미지를 AI로 제작해 동남아인들의 외모를 비하자 인도네시아를 비롯한 동남아 네티즌들은 인종 차별이라며 한국 산업에 관해 보이콧 참여를 동료하기도 했습니다. 한편 한국과 동남아 네티즌들은 K팝의 전 세계적인 인기와 관련해 동남화팬 기어도를 두고 해외 사이트에서 설전을 버려온 바 있는데요. 일각에서는 오랫동안 쌓여온 갈등이 이번케팝 공연 사건을 통해 폭발했다고 진단했습니다. 입니다.')]

# %%
for v in videos:
    v['video_url'] = 'https://youtube.com' + v['url_suffix']

    loader = YoutubeLoader.from_youtube_url(
        v['video_url'],
        language=['ko', 'en']
    )

    v['content'] = loader.load()

videos
# Out:
# [{'id': 'vP_8LacSzts',
#   'thumbnails': ['https://i.ytimg.com/vi/vP_8LacSzts/hq720_2.jpg?sqp=-oaymwE9COgCEMoBSFryq4qpAy8IARUAAAAAGAAlAADIQj0AgKJDeAHwAQH4AbYIgAKAD4oCDAgAEAEYZSBWKEgwDw==&rs=AOn4CLAqsOMa5ecp2jgSAOCTylKKQtK64Q',
#    'https://i.ytimg.com/vi/vP_8LacSzts/hq720_2.jpg?sqp=-oaymwExCNAFEJQDSFryq4qpAyMIARUAAIhCGADwAQH4AbYIgAKAD4oCDAgAEAEYZSBWKEgwDw==&rs=AOn4CLBe8li57db8nk9PCkAckI9wjMyxFg'],
#   'title': '한국인은 ‘인종차별주의자‘? 논란의 인도네시아 팬덤',
#   'long_desc': None,
#   'channel': '비사일',
#   'duration': '0:35',
#   'views': '조회수 1,482회',
#   'publish_time': '3주 전',
#   'url_suffix': '/shorts/vP_8LacSzts',
#   'video_url': 'https://youtube.com/shorts/vP_8LacSzts',
#   'content': [Document(metadata={'source': 'vP_8LacSzts'}, page_content='한국인은 인종 차별주의자다. 최근 말오고 있다는 카르맨의 인도네시아 팬덤. 최근 카르맨의 인도네시아 팬덤에 대한 한국 팬들의 불만이 나오고 있다. 그 이유는 바로 카르맨의 인도네시아 팬들이 한국인을 사칭하며 한국어로 번역까지 하면서 카르맨을 칭찬하고 한국은 서쪽 일본이다. 한국인들은 외국 아이돌들을 등한시한다. 한국인들은 인종차별 주의자이다. 심지어는 한국인들의 외모까지 비하하기도 한다. 등등의 각종 뇌 피셜들로 한국 팬들을 골치 아프게 하고 있다고 한다. 여러분들의 생각은?')]},
#  {'id': 'tJssmxMOuEA',
#   'thumbnails': ['https://i.ytimg.com/vi/tJssmxMOuEA/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDd80o9cK1jwY-I8I7hUsUP6SkzyA',
#    'https://i.ytimg.com/vi/tJssmxMOuEA/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLA5qjyBXWg-LN9_b7PMuYSLLDYATA'],
#   'title': '"원숭이" 인종차별 논란…파푸아 유혈사태 격화 / 연합뉴스TV (YonhapnewsTV)',
#   'long_desc': None,
#   'channel': '연합뉴스TV',
#   'duration': '1:44',
#   'views': '조회수 808회',
#   'publish_time': '6년 전',
#   'url_suffix': '/watch?v=tJssmxMOuEA&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'video_url': 'https://youtube.com/watch?v=tJssmxMOuEA&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'content': [Document(metadata={'source': 'tJssmxMOuEA'}, page_content='인도네시아 령 파프 하에서 인종차별 논란에 따른 유혈사태로 익명 피해가 늘고 있습니다 한동안 잠잠했던 반 정 보 12 가 다시 불붙는 모습입니다 김효석 pd 입니다 건물 곳곳에 검은 연기가 피어오릅니다 무장한 군인과 시위대 간 긴장감이 팽팽한 입니다 인도네시아 령 화포 하에서 계속되는 반정부 시위로 수십명의 사상자가 발생했습니다 시위를 촉발시킨 것은 원숭이 라고 불렀다는 소문이 얻습니다 1 오늘 와 깐깐한 나갈 수 있어 아 제발 제발 부탁이야 말했다 아 하지만 인종차별적 발언 의 사실 여부는 확인되지 않은 상황 좋고 의도도 인도네시아 대통령이 수습에 났었지만 유혈사태는 잦아들지 않고 있습니다 파푸아 지역의 반정부 시위는 뿌리기 푼 인종차별에 대한 불만 에서 비롯되었습니다 불과 한 달 전에도 파푸아 출신 대학생들이 국회 훼손 혐의로 경찰에 붙잡힐 때 원숭이나 돼지 로 불리는 동영상이 유포돼 논란이 됐습니다 당시 분노한 주민들이 거리로 나섰고 정부는 소요 사태를 진정시키려 수천명의 군인과 경찰을 투입한 바 있습니다 50년전 주민투표로 인도네시아의 통합된 뒤 분리주의 운동 이 이어져오고 있는 파푸와 인도네시아 정부의 적극적인 민심 달래기 가 시급해 보입니다 연합뉴스 tv 김요섭 입니다')]},
#  {'id': 'RyhD_2XJbPI',
#   'thumbnails': ['https://i.ytimg.com/vi/RyhD_2XJbPI/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDC_EitzBFK2qjZZYdSoxCQPqmh9Q',
#    'https://i.ytimg.com/vi/RyhD_2XJbPI/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDC0v3rfyuEaHIAStyWR4yEYaCJrA'],
#   'title': '[라디오스타] 인종차별러 참교육👊 현지 텃세 이겨낸 명예영국인의 무적 필살기, MBC 260218 방송',
#   'long_desc': None,
#   'channel': 'MBCentertainment',
#   'duration': '3:25',
#   'views': '조회수 167,180회',
#   'publish_time': '1일 전',
#   'url_suffix': '/watch?v=RyhD_2XJbPI&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'video_url': 'https://youtube.com/watch?v=RyhD_2XJbPI&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'content': [Document(metadata={'source': 'RyhD_2XJbPI'}, page_content='자, 우리 저기 연구상제 7년하셨는데 우리 명예 영국인 씨가 영국인이 척할 수 있는 부적의 표현들 알려주겠다는 네요. 예. >> 일단 이제 영국가 가지고 하이 how are유 하면 짜바리에요. 완전 >> 짜바리. >> 일단 영국은 인사가 right >> 예 괜찮니? 이런게 인사예요. >> 그래서 네. 항상 얘기할 때 you right how are you? 아 >> 보는 사람한테도요. >> 그럼요. 이웃이 이렇게 지나갈 때도 그냥 >> 미국에서 약간 이상해 보일 때라 하잖아요. >> 맞아요. 그래서 약간 기분 나빠시는 분도 있어요. 딱 괜찮은데 왜 물어보세요 약간 이렇게 >> 예 근데 오해 안 하시면 되고 이제 대박 어 미쳤다. >> 아유트 >> 아유 >> 아유트 >> 아유트네 >> 원래 매드인데 >> 영국시로 바꾸면 트 >> 아 >> 맛유 맛 >> 그리고 부가 의무문을 맛있어요. 아시죠? 뭐 이런 걸 많이 이알예 이런 거 it >> 예 그래서 이을 in it >> 맞아 [웃음] >> 왜냐면 의모문 할 때 영국은 올리지 않아요 그지 미국이 약간 are you hungry 이렇게 올리잖아요 근데 영국은 >> are hungry 이렇게 내려요. 의문이 >> 의무문이에요. 그래서 물어보는 거를 사람들이 모르잖아요. >> 그래서 부가 의무문을 붙이는 겁니다. 끝에 거에다가 >> 아 좋아리네 이런 식으로 >> 올리긴 하네. 그리 영 사람들은 땡큐 발음 있잖아요. >> 그걸 F로 바꿔요. 그자 땡큐 이렇게 안 하고 >> 땡큐 >> 땡큐 >> 어 땡큐 땡큐 >> 좀 나쁘게 들리는데 >> 왜요 이렇게 땡큐 >> 땡큐 >> 근데 이것도 귀찮아 왜냐면 실생활에 연구 사람들 맨날 고맙다는 말을 하니까 이것도 좀 귀찮으니까 치즈 >> 음 >> 치어스 치어스 이거 치즈 >> 알바르면 빼야 되잖아요 영국치 >> 알바르면은 극히 싫어하는 거 >> 정말 싫어 티바음 알바름 >> 지금 알바름의 대가는 저기 >> 그래서 제가 네. >> 인데 >> 일단 나가 있을까? [웃음] >> 자, 자랑스러운 대한애 딸입니다. 명예 영국인. 예. 인종차별 대처 필승법도 전술를 해 주겠다고요. >> 맞아요. 미국 인종차별 약간 대놓고요. 막 칭창 막 이렇게. >> 그 유럽은 좀 돌려서 해요. 만약에 내가 한국에서 산 코리아 그러면은 >> 김정은 혹시 알아? 이런 식으로 >> 그런 식으로 기분 나쁘게 >> 어 다 알면서 그래서 그럴 때는 그냥 기세로 가야 돼요. 그래서 그 유럽은 약간 인종차별을 하는게 좀 범죄거든요. 사실 그래서 크게 소리를 지르면 돼요. >> 어 >> 막 이렇게 소리를 사람들의 이목이 집중이 돼. >> 집중이 >> 그래 김정을 한다. 왜? >> 어 맞아요. [웃음] >> 내 아빠야. >> 내 아버지야. 막 이러고 갑자기 전화 >> 전화하는 척 >> 그래서 a >> 전 >> 금발 60대 [웃음] 이런 식으로 하면은 놀래서 도망가 >> 기세네 역시 기세 >> 기세로 Ah.')]},
#  {'id': 'eMvKaLucrkU',
#   'thumbnails': ['https://i.ytimg.com/vi/eMvKaLucrkU/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCvDlDT-BoSPpDsKpRs6Ywx_Bywqw',
#    'https://i.ytimg.com/vi/eMvKaLucrkU/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDNz3tmwOFMJqw6sRTXF1npgxitfQ'],
#   'title': "K팝 비하부터 독립운동가 조롱까지…동남아 혐한에 韓 네티즌들 '폭발'",
#   'long_desc': None,
#   'channel': '뉴스1TV',
#   'duration': '3:39',
#   'views': '조회수 850회',
#   'publish_time': '45분 전',
#   'url_suffix': '/watch?v=eMvKaLucrkU&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'video_url': 'https://youtube.com/watch?v=eMvKaLucrkU&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'content': [Document(metadata={'source': 'eMvKaLucrkU'}, page_content='Oin netizen-netizen Korea tuh o. Hei dengar ya idol kalian tanpa netizen Indonesia bisa apa? Kerasa pasok inom 동남아시아 젊은 세대 사이에서 최근 사회관계망 서비스를 중심으로 혐한 정서가 고조되고 있습니다. 말레이시아와 인도네시아, 베트남, 태국, 필리핀 등 동남아 네티즌들은 21엑와 틱톡 등 소셜 미디어를 통해 한국인이 인종 차별한다는 취지에 글과 영상을 개제했는데요. 이들은 동남아의 형제 자매들이 연대한다는 뜻을 지닌 합성어 시블링이란 해시태그를 달면서 한국은 인종차별주의 국가라고 주장했습니다. 이러한 동남안의 혐한 정서는 지난달 31일 말레이시아에서 열린 한국 보이그룹 데이스 공연이 기폭제가 됐는데요. 당시 현지 임페는 공연에서 반입 금지된 대형 렌즈가 달린 카메라 즉 대포 카메라로 촬영하다 발각된 한국인 팬을 겨냥해 콘서트 관람 매너를 꼬집었다는 전원입니다. 이후 비난 여론이 들끌 대포 카메라로 촬영했던 팬이 사과를 개시했지만 동남아 네티즌들은 문제된 팬의 신상 정보 및 사진을 무단으로 퍼날랐고 한국 사회 전반 또한 비난한 것으로 알려졌는데요. 이에 한국 네티즌들은 선넘은 신상토리와 공격에 분노하면서팝 인기를 질투해 근거없는 발언을 일삼고 있다며 반격했고 한국과 동남아간 감정섞인 신랑이가 이어졌습니다. 동남아 네티즌들은 한국의 의식주 독립운동과 대형참사 희생자들을 비하하는가 하면 하얀 피부색을 선망하는 성형 괴물이 가득한 나라고 조롱했는데요. 그러면서 한국이 동남아 국가 덕분에 가난으로부터 벗어났다며 닭장 같은 아파트에서 사는 한국을 우리가 먹여 살린다고 주장해 공분을 샀습니다. 한국 네티즌들은 우리나라에서 이민자 코터로 쉽게 취업해 돈 벌어 가는 동남아인들이 혐만을 하느냐며 이게하고 교육을 못 받은 거짓대들이라고 맞불을 낳는데요. 이어 체급이 비슷해야 싸울 맛이 나는데 그곳에서 인터넷은 되느냐며 우리는 원래 피부색이 밝은 편이다. 열등감에 가득찬 동남아인들이 한국을 시샘에 사실을 왜곡하고 있다라고 덧붙였습니다. 특히 한국인의 피부색은 가짜라며 혐안을 주도하는 인도네시아에 대해선 뒤통수쳐서 떼먹은 KF21 분담금이나 가프라고 경로했는데요. 한국 네티즌들이 원숭이와 오랑오탄 등 동물 이미지를 AI로 제작해 동남아인들의 외모를 비하자 인도네시아를 비롯한 동남아 네티즌들은 인종 차별이라며 한국 산업에 관해 보이콧 참여를 동료하기도 했습니다. 한편 한국과 동남아 네티즌들은 K팝의 전 세계적인 인기와 관련해 동남화팬 기어도를 두고 해외 사이트에서 설전을 버려온 바 있는데요. 일각에서는 오랫동안 쌓여온 갈등이 이번케팝 공연 사건을 통해 폭발했다고 진단했습니다. 입니다.')]},
#  {'id': 'YI3efB1sawc',
#   'thumbnails': ['https://i.ytimg.com/vi/YI3efB1sawc/hq720.jpg?sqp=-oaymwE9COgCEMoBSFryq4qpAy8IARUAAAAAGAAlAADIQj0AgKJDeAHwAQH4AbYIgAKAD4oCDAgAEAEYciBMKEAwDw==&rs=AOn4CLCCfVDrLuFGtuQVf4m4_gQqAbeC3Q',
#    'https://i.ytimg.com/vi/YI3efB1sawc/hq720.jpg?sqp=-oaymwExCNAFEJQDSFryq4qpAyMIARUAAIhCGADwAQH4AbYIgAKAD4oCDAgAEAEYciBMKEAwDw==&rs=AOn4CLADnn2Ai0wS2pgDQAqD8yIQ8te2ag'],
#   'title': '한국인은 모르는 한국인의 인종차별',
#   'long_desc': None,
#   'channel': 'Creative Den',
#   'duration': '0:43',
#   'views': '조회수 86,915회',
#   'publish_time': '8개월 전',
#   'url_suffix': '/shorts/YI3efB1sawc',
#   'video_url': 'https://youtube.com/shorts/YI3efB1sawc',
#   'content': [Document(metadata={'source': 'YI3efB1sawc'}, page_content='처음에 이제 뭐 한국말 잘한다 막 이런 칭찬 받을 때 당연히 좋았는데 지금은 그냥 조금 그렇죠 독일에서는 그냥 저는 누가 독일 있는지도 알 이젠 알 수 없잖아요 다들 이미 인종때 되게 많이 섞어 가지고 제가 누구를 독일에서 말을 실 때 영어로 먼저 말 걸리고 와 독기로 잘하네 절대로 이런 얘기 안 할 거야 뭐 물론 한국말 잘한다 그거는 나쁜 건 아닌데 어디서 왔냐 가지는 괜찮아요 근데 갑자기 러시에서 왔어요 영국에서 왔어요 아기 가지고 안 그 무르보 아닌 것도 알지만 한국인 외국인 에서 만약에 막 are you from China 당하는게 똑같아요 왜 사람의 메모 보고이 사람 국적을 맞추려고 하는 건지도 모르겠고 그래도 한 달에 한 세네 번씩이 그러면 9년 살았으면 얼마나 많이 그런 일들이 있었을텐데 맞아요')]}]

# %%
print('총 영상 수:', len(videos))

videos = [v for v in videos if len(v['duration'].split(':')) < 3]

print('60분 이하 영상 수: ', len(videos))
# Out:
# 총 영상 수: 5
# 60분 이하 영상 수:  5

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini")

model.invoke("안녕?")
# Out:
# AIMessage(content='안녕하세요! 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 10, 'total_tokens': 20, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DBHJTH2xJNwp2abqts9PqVWbJk3r2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c7a6d-9e01-7db1-bb2a-5e585761d529-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 10, 'total_tokens': 20, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains.combine_documents import create_stuff_documents_chain

# 동영상 요약 프롬프트 작성 
prompt = ChatPromptTemplate.from_messages(
    [('system', "다음 영상에 대한 요약을 한국어로 만들어줘 :\\n\\n{context}")]
)

chain = create_stuff_documents_chain(model, prompt)

result = chain.invoke({'context': videos[0]['content']})
result
# Out:
# '영상에서는 최근 인도네시아의 카르맨 팬덤과 관련하여 한국 팬들이 느끼는 불만에 대해 이야기하고 있습니다. 인도네시아 팬들이 한국인을 사칭하고 한국어로 번역하여 카르맨을 칭찬하는 행위가 문제로 지적되고 있으며, 한국 팬들은 외국 아이돌에 대한 소홀함과 함께 한국인에 대한 인종 차별주의적 발언이 많다고 주장하고 있습니다. 이러한 상황으로 인해 한국 팬들이 고통을 받고 있다는 내용이 담겨 있습니다. 마지막으로, 이와 관련해 시청자들에게 의견을 묻고 있습니다.'

# %%
from tqdm import tqdm # 진행 상황을 보여주는 라이브러리 

for v in tqdm(videos):
    v['summary'] = chain.invoke({'context': v['content']})

videos
# Out:
# 100%|██████████| 5/5 [00:22<00:00,  4.50s/it]
# [{'id': 'vP_8LacSzts',
#   'thumbnails': ['https://i.ytimg.com/vi/vP_8LacSzts/hq720_2.jpg?sqp=-oaymwE9COgCEMoBSFryq4qpAy8IARUAAAAAGAAlAADIQj0AgKJDeAHwAQH4AbYIgAKAD4oCDAgAEAEYZSBWKEgwDw==&rs=AOn4CLAqsOMa5ecp2jgSAOCTylKKQtK64Q',
#    'https://i.ytimg.com/vi/vP_8LacSzts/hq720_2.jpg?sqp=-oaymwExCNAFEJQDSFryq4qpAyMIARUAAIhCGADwAQH4AbYIgAKAD4oCDAgAEAEYZSBWKEgwDw==&rs=AOn4CLBe8li57db8nk9PCkAckI9wjMyxFg'],
#   'title': '한국인은 ‘인종차별주의자‘? 논란의 인도네시아 팬덤',
#   'long_desc': None,
#   'channel': '비사일',
#   'duration': '0:35',
#   'views': '조회수 1,482회',
#   'publish_time': '3주 전',
#   'url_suffix': '/shorts/vP_8LacSzts',
#   'video_url': 'https://youtube.com/shorts/vP_8LacSzts',
#   'content': [Document(metadata={'source': 'vP_8LacSzts'}, page_content='한국인은 인종 차별주의자다. 최근 말오고 있다는 카르맨의 인도네시아 팬덤. 최근 카르맨의 인도네시아 팬덤에 대한 한국 팬들의 불만이 나오고 있다. 그 이유는 바로 카르맨의 인도네시아 팬들이 한국인을 사칭하며 한국어로 번역까지 하면서 카르맨을 칭찬하고 한국은 서쪽 일본이다. 한국인들은 외국 아이돌들을 등한시한다. 한국인들은 인종차별 주의자이다. 심지어는 한국인들의 외모까지 비하하기도 한다. 등등의 각종 뇌 피셜들로 한국 팬들을 골치 아프게 하고 있다고 한다. 여러분들의 생각은?')],
#   'summary': '영상에서는 최근 카르맨의 인도네시아 팬덤에 대한 한국 팬들의 불만을 다루고 있습니다. 불만의 주된 이유는 인도네시아 팬들이 한국인을 사칭하며 한국어로 번역해 카르맨을 칭찬하고, 한국을 서쪽 일본이라고 표현하는 등 한국 팬들에게 부정적인 인상을 주고 있다는 것입니다. 또한 한국인들이 외국 아이돌을 소홀히 여기고, 심지어 한국인의 외모를 비하하는 등의 인종차별적인 행동이 문제로 지적되고 있습니다. 이러한 내용들을 통해 한국 팬들이 곤란을 겪고 있다는 주장을 담고 있으며, 영상은 시청자들에게 이 문제에 대한 의견을 묻고 있습니다.'},
#  {'id': 'tJssmxMOuEA',
#   'thumbnails': ['https://i.ytimg.com/vi/tJssmxMOuEA/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDd80o9cK1jwY-I8I7hUsUP6SkzyA',
#    'https://i.ytimg.com/vi/tJssmxMOuEA/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLA5qjyBXWg-LN9_b7PMuYSLLDYATA'],
#   'title': '"원숭이" 인종차별 논란…파푸아 유혈사태 격화 / 연합뉴스TV (YonhapnewsTV)',
#   'long_desc': None,
#   'channel': '연합뉴스TV',
#   'duration': '1:44',
#   'views': '조회수 808회',
#   'publish_time': '6년 전',
#   'url_suffix': '/watch?v=tJssmxMOuEA&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'video_url': 'https://youtube.com/watch?v=tJssmxMOuEA&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'content': [Document(metadata={'source': 'tJssmxMOuEA'}, page_content='인도네시아 령 파프 하에서 인종차별 논란에 따른 유혈사태로 익명 피해가 늘고 있습니다 한동안 잠잠했던 반 정 보 12 가 다시 불붙는 모습입니다 김효석 pd 입니다 건물 곳곳에 검은 연기가 피어오릅니다 무장한 군인과 시위대 간 긴장감이 팽팽한 입니다 인도네시아 령 화포 하에서 계속되는 반정부 시위로 수십명의 사상자가 발생했습니다 시위를 촉발시킨 것은 원숭이 라고 불렀다는 소문이 얻습니다 1 오늘 와 깐깐한 나갈 수 있어 아 제발 제발 부탁이야 말했다 아 하지만 인종차별적 발언 의 사실 여부는 확인되지 않은 상황 좋고 의도도 인도네시아 대통령이 수습에 났었지만 유혈사태는 잦아들지 않고 있습니다 파푸아 지역의 반정부 시위는 뿌리기 푼 인종차별에 대한 불만 에서 비롯되었습니다 불과 한 달 전에도 파푸아 출신 대학생들이 국회 훼손 혐의로 경찰에 붙잡힐 때 원숭이나 돼지 로 불리는 동영상이 유포돼 논란이 됐습니다 당시 분노한 주민들이 거리로 나섰고 정부는 소요 사태를 진정시키려 수천명의 군인과 경찰을 투입한 바 있습니다 50년전 주민투표로 인도네시아의 통합된 뒤 분리주의 운동 이 이어져오고 있는 파푸와 인도네시아 정부의 적극적인 민심 달래기 가 시급해 보입니다 연합뉴스 tv 김요섭 입니다')],
#   'summary': '인도네시아 령 파푸아 지역에서 인종차별 논란으로 인해 유혈사태가 발생하고 있으며, 반정부 시위가 다시 활발해지고 있습니다. 시위는 원숭이라는 인종차별적 발언이 전해지면서 촉발되었고, 이는 아직 확인되지 않은 소문입니다. 대통령은 상황 수습에 나섰지만 사태는 진정되지 않고 있으며, 수십 명의 사상자가 발생했습니다. 최근에도 파푸아 출신 대학생들이 경찰에 붙잡히며 인종차별적 발언이 담긴 동영상이 유포되면서 주민들의 분노를 초래했습니다. 현재 정부는 군인과 경찰을 대거 투입하여 소요 사태를 진정시키려 하고 있으며, 파푸아 지역의 반정부 시위는 뿌리 깊은 인종차별에 대한 불만에서 비롯되고 있습니다. 인도네시아 정부의 신속한 민심 달래기 노력이 필요해 보입니다.'},
#  {'id': 'RyhD_2XJbPI',
#   'thumbnails': ['https://i.ytimg.com/vi/RyhD_2XJbPI/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLDC_EitzBFK2qjZZYdSoxCQPqmh9Q',
#    'https://i.ytimg.com/vi/RyhD_2XJbPI/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDC0v3rfyuEaHIAStyWR4yEYaCJrA'],
#   'title': '[라디오스타] 인종차별러 참교육👊 현지 텃세 이겨낸 명예영국인의 무적 필살기, MBC 260218 방송',
#   'long_desc': None,
#   'channel': 'MBCentertainment',
#   'duration': '3:25',
#   'views': '조회수 167,180회',
#   'publish_time': '1일 전',
#   'url_suffix': '/watch?v=RyhD_2XJbPI&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'video_url': 'https://youtube.com/watch?v=RyhD_2XJbPI&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'content': [Document(metadata={'source': 'RyhD_2XJbPI'}, page_content='자, 우리 저기 연구상제 7년하셨는데 우리 명예 영국인 씨가 영국인이 척할 수 있는 부적의 표현들 알려주겠다는 네요. 예. >> 일단 이제 영국가 가지고 하이 how are유 하면 짜바리에요. 완전 >> 짜바리. >> 일단 영국은 인사가 right >> 예 괜찮니? 이런게 인사예요. >> 그래서 네. 항상 얘기할 때 you right how are you? 아 >> 보는 사람한테도요. >> 그럼요. 이웃이 이렇게 지나갈 때도 그냥 >> 미국에서 약간 이상해 보일 때라 하잖아요. >> 맞아요. 그래서 약간 기분 나빠시는 분도 있어요. 딱 괜찮은데 왜 물어보세요 약간 이렇게 >> 예 근데 오해 안 하시면 되고 이제 대박 어 미쳤다. >> 아유트 >> 아유 >> 아유트 >> 아유트네 >> 원래 매드인데 >> 영국시로 바꾸면 트 >> 아 >> 맛유 맛 >> 그리고 부가 의무문을 맛있어요. 아시죠? 뭐 이런 걸 많이 이알예 이런 거 it >> 예 그래서 이을 in it >> 맞아 [웃음] >> 왜냐면 의모문 할 때 영국은 올리지 않아요 그지 미국이 약간 are you hungry 이렇게 올리잖아요 근데 영국은 >> are hungry 이렇게 내려요. 의문이 >> 의무문이에요. 그래서 물어보는 거를 사람들이 모르잖아요. >> 그래서 부가 의무문을 붙이는 겁니다. 끝에 거에다가 >> 아 좋아리네 이런 식으로 >> 올리긴 하네. 그리 영 사람들은 땡큐 발음 있잖아요. >> 그걸 F로 바꿔요. 그자 땡큐 이렇게 안 하고 >> 땡큐 >> 땡큐 >> 어 땡큐 땡큐 >> 좀 나쁘게 들리는데 >> 왜요 이렇게 땡큐 >> 땡큐 >> 근데 이것도 귀찮아 왜냐면 실생활에 연구 사람들 맨날 고맙다는 말을 하니까 이것도 좀 귀찮으니까 치즈 >> 음 >> 치어스 치어스 이거 치즈 >> 알바르면 빼야 되잖아요 영국치 >> 알바르면은 극히 싫어하는 거 >> 정말 싫어 티바음 알바름 >> 지금 알바름의 대가는 저기 >> 그래서 제가 네. >> 인데 >> 일단 나가 있을까? [웃음] >> 자, 자랑스러운 대한애 딸입니다. 명예 영국인. 예. 인종차별 대처 필승법도 전술를 해 주겠다고요. >> 맞아요. 미국 인종차별 약간 대놓고요. 막 칭창 막 이렇게. >> 그 유럽은 좀 돌려서 해요. 만약에 내가 한국에서 산 코리아 그러면은 >> 김정은 혹시 알아? 이런 식으로 >> 그런 식으로 기분 나쁘게 >> 어 다 알면서 그래서 그럴 때는 그냥 기세로 가야 돼요. 그래서 그 유럽은 약간 인종차별을 하는게 좀 범죄거든요. 사실 그래서 크게 소리를 지르면 돼요. >> 어 >> 막 이렇게 소리를 사람들의 이목이 집중이 돼. >> 집중이 >> 그래 김정을 한다. 왜? >> 어 맞아요. [웃음] >> 내 아빠야. >> 내 아버지야. 막 이러고 갑자기 전화 >> 전화하는 척 >> 그래서 a >> 전 >> 금발 60대 [웃음] 이런 식으로 하면은 놀래서 도망가 >> 기세네 역시 기세 >> 기세로 Ah.')],
#   'summary': '이 영상에서는 한 명의 연구자가 영국에서의 대화 방식과 인사법, 그리고 인종차별에 대한 대처법에 대해 설명합니다. 먼저, 영국에서 일반적인 인사로 "How are you?" 대신 "You alright?"를 사용하는 것을 소개하며, 이 인사가 미국식과는 다르게 느껴질 수 있다는 점도 언급합니다. 또한, 영국 사람들은 의문문을 말할 때 어조를 내리지 않고 붙이기 어렵지만, "Isn\'t it?"와 같은 표현을 자주 사용한다고 설명합니다. \n\n발음의 차이점도 강조되며, "Thank you"를 "Thank you" 대신 "Cheers"로 줄여 말하는 것을 추천합니다. 마지막으로, 유럽에서는 인종차별이 돌려서 표현되는 경우가 많고, 이에 대한 대처법으로는 상황을 과장해 사람들의 주목을 끌어야 한다고 조언합니다. 영상은 영국 문화와 대처법에 대한 유익한 팁을 제공하고 있습니다.'},
#  {'id': 'eMvKaLucrkU',
#   'thumbnails': ['https://i.ytimg.com/vi/eMvKaLucrkU/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLCvDlDT-BoSPpDsKpRs6Ywx_Bywqw',
#    'https://i.ytimg.com/vi/eMvKaLucrkU/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDNz3tmwOFMJqw6sRTXF1npgxitfQ'],
#   'title': "K팝 비하부터 독립운동가 조롱까지…동남아 혐한에 韓 네티즌들 '폭발'",
#   'long_desc': None,
#   'channel': '뉴스1TV',
#   'duration': '3:39',
#   'views': '조회수 850회',
#   'publish_time': '45분 전',
#   'url_suffix': '/watch?v=eMvKaLucrkU&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'video_url': 'https://youtube.com/watch?v=eMvKaLucrkU&pp=ygUc7J2464-E64Sk7Iuc7JWEIOyduOyiheywqOuzhA%3D%3D',
#   'content': [Document(metadata={'source': 'eMvKaLucrkU'}, page_content='Oin netizen-netizen Korea tuh o. Hei dengar ya idol kalian tanpa netizen Indonesia bisa apa? Kerasa pasok inom 동남아시아 젊은 세대 사이에서 최근 사회관계망 서비스를 중심으로 혐한 정서가 고조되고 있습니다. 말레이시아와 인도네시아, 베트남, 태국, 필리핀 등 동남아 네티즌들은 21엑와 틱톡 등 소셜 미디어를 통해 한국인이 인종 차별한다는 취지에 글과 영상을 개제했는데요. 이들은 동남아의 형제 자매들이 연대한다는 뜻을 지닌 합성어 시블링이란 해시태그를 달면서 한국은 인종차별주의 국가라고 주장했습니다. 이러한 동남안의 혐한 정서는 지난달 31일 말레이시아에서 열린 한국 보이그룹 데이스 공연이 기폭제가 됐는데요. 당시 현지 임페는 공연에서 반입 금지된 대형 렌즈가 달린 카메라 즉 대포 카메라로 촬영하다 발각된 한국인 팬을 겨냥해 콘서트 관람 매너를 꼬집었다는 전원입니다. 이후 비난 여론이 들끌 대포 카메라로 촬영했던 팬이 사과를 개시했지만 동남아 네티즌들은 문제된 팬의 신상 정보 및 사진을 무단으로 퍼날랐고 한국 사회 전반 또한 비난한 것으로 알려졌는데요. 이에 한국 네티즌들은 선넘은 신상토리와 공격에 분노하면서팝 인기를 질투해 근거없는 발언을 일삼고 있다며 반격했고 한국과 동남아간 감정섞인 신랑이가 이어졌습니다. 동남아 네티즌들은 한국의 의식주 독립운동과 대형참사 희생자들을 비하하는가 하면 하얀 피부색을 선망하는 성형 괴물이 가득한 나라고 조롱했는데요. 그러면서 한국이 동남아 국가 덕분에 가난으로부터 벗어났다며 닭장 같은 아파트에서 사는 한국을 우리가 먹여 살린다고 주장해 공분을 샀습니다. 한국 네티즌들은 우리나라에서 이민자 코터로 쉽게 취업해 돈 벌어 가는 동남아인들이 혐만을 하느냐며 이게하고 교육을 못 받은 거짓대들이라고 맞불을 낳는데요. 이어 체급이 비슷해야 싸울 맛이 나는데 그곳에서 인터넷은 되느냐며 우리는 원래 피부색이 밝은 편이다. 열등감에 가득찬 동남아인들이 한국을 시샘에 사실을 왜곡하고 있다라고 덧붙였습니다. 특히 한국인의 피부색은 가짜라며 혐안을 주도하는 인도네시아에 대해선 뒤통수쳐서 떼먹은 KF21 분담금이나 가프라고 경로했는데요. 한국 네티즌들이 원숭이와 오랑오탄 등 동물 이미지를 AI로 제작해 동남아인들의 외모를 비하자 인도네시아를 비롯한 동남아 네티즌들은 인종 차별이라며 한국 산업에 관해 보이콧 참여를 동료하기도 했습니다. 한편 한국과 동남아 네티즌들은 K팝의 전 세계적인 인기와 관련해 동남화팬 기어도를 두고 해외 사이트에서 설전을 버려온 바 있는데요. 일각에서는 오랫동안 쌓여온 갈등이 이번케팝 공연 사건을 통해 폭발했다고 진단했습니다. 입니다.')],
#   'summary': "최근 동남아시아 젊은 세대 사이에서 한국에 대한 혐오 정서가 고조되고 있습니다. 말레이시아, 인도네시아, 베트남, 태국, 필리핀 등의 네티즌들이 한국인의 인종 차별에 대한 비판을 담은 글과 영상을 소셜 미디어에 올리고 있습니다. 이들은 '시블링'이라는 해시태그를 사용하며 한국을 인종차별 국가로 주장하고 있습니다.\n\n이러한 갈등은 말레이시아에서 열린 한국 보이그룹 '데이스'의 공연 중 한국인 팬이 대포 카메라로 촬영하다가 발각된 사건을 계기로 촉발되었습니다. 이후 해당 팬은 사과했지만, 동남아 네티즌들은 팬의 개인 정보를 무단으로 유포하며 한국 사회 전체에 대한 비난이 이어졌습니다. 한국 네티즌들은 이에 반격하며 동남아의 혐한 정서를 조롱하고, 동남아인들이 한국에서 쉽게 취업하는 것에 대해 언급했습니다.\n\n양측의 갈등은 한국인의 피부색과 외모에 대한 조롱으로 번지며, 동남아 네티즌들이 한국 산업에 대한 보이콧을 주장하는 상황에 이르렀습니다. K팝의 세계적인 인기와 관련하여 지속된 갈등이 이번 사건을 통해 폭발한 것으로 분석되고 있습니다."},
#  {'id': 'YI3efB1sawc',
#   'thumbnails': ['https://i.ytimg.com/vi/YI3efB1sawc/hq720.jpg?sqp=-oaymwE9COgCEMoBSFryq4qpAy8IARUAAAAAGAAlAADIQj0AgKJDeAHwAQH4AbYIgAKAD4oCDAgAEAEYciBMKEAwDw==&rs=AOn4CLCCfVDrLuFGtuQVf4m4_gQqAbeC3Q',
#    'https://i.ytimg.com/vi/YI3efB1sawc/hq720.jpg?sqp=-oaymwExCNAFEJQDSFryq4qpAyMIARUAAIhCGADwAQH4AbYIgAKAD4oCDAgAEAEYciBMKEAwDw==&rs=AOn4CLADnn2Ai0wS2pgDQAqD8yIQ8te2ag'],
#   'title': '한국인은 모르는 한국인의 인종차별',
#   'long_desc': None,
#   'channel': 'Creative Den',
#   'duration': '0:43',
#   'views': '조회수 86,915회',
#   'publish_time': '8개월 전',
#   'url_suffix': '/shorts/YI3efB1sawc',
#   'video_url': 'https://youtube.com/shorts/YI3efB1sawc',
#   'content': [Document(metadata={'source': 'YI3efB1sawc'}, page_content='처음에 이제 뭐 한국말 잘한다 막 이런 칭찬 받을 때 당연히 좋았는데 지금은 그냥 조금 그렇죠 독일에서는 그냥 저는 누가 독일 있는지도 알 이젠 알 수 없잖아요 다들 이미 인종때 되게 많이 섞어 가지고 제가 누구를 독일에서 말을 실 때 영어로 먼저 말 걸리고 와 독기로 잘하네 절대로 이런 얘기 안 할 거야 뭐 물론 한국말 잘한다 그거는 나쁜 건 아닌데 어디서 왔냐 가지는 괜찮아요 근데 갑자기 러시에서 왔어요 영국에서 왔어요 아기 가지고 안 그 무르보 아닌 것도 알지만 한국인 외국인 에서 만약에 막 are you from China 당하는게 똑같아요 왜 사람의 메모 보고이 사람 국적을 맞추려고 하는 건지도 모르겠고 그래도 한 달에 한 세네 번씩이 그러면 9년 살았으면 얼마나 많이 그런 일들이 있었을텐데 맞아요')],
#   'summary': '이 영상에서는 한국어를 잘한다는 칭찬이 처음에는 좋았지만, 지금은 그리 긍정적으로 느껴지지 않는다는 이야기를 하고 있습니다. 특히 독일에서 살고 있는 저자는 다양한 인종이 섞여 있는 환경에서는 누가 한국인인지 알기 어렵고, 대화를 시작할 때 영어로 말 걸기를 주로 경험한다고 합니다. 한국어 능력에 대해 칭찬받는 것이 나쁘지 않지만, 외국인으로서 겪는 국적에 대한 오해나 편견에 대해서는 불편함을 느낀다고 전합니다. 자신이 9년 동안 독일에 살면서 그러한 경험을 자주 했다며, 사람들의 국적을 쉽게 판단하려는 태도에 대한 의문도 제기합니다.'}]
