# %%
# %pip install --upgrade pip
# %pip install --upgrade transformers datasets accelerate
# Out:
# Requirement already satisfied: pip in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (26.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (4.56.2)
# Collecting transformers
#   Downloading transformers-5.1.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: datasets in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (4.5.0)
# Requirement already satisfied: accelerate in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (1.12.0)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers)
#   Downloading huggingface_hub-1.4.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from transformers) (2.3.0)
# Requirement already satisfied: packaging>=20.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from datasets) (23.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: xxhash in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from datasets) (0.70.18)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: psutil in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: torch>=2.0.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from accelerate) (2.10.0+cpu)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: sympy>=1.13.3 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in d:\projects\gpt_agent_2025_book\venv\Lib\site-packages (from typer-slim->transformers) (8.3.1)
# Downloading transformers-5.1.0-py3-none-any.whl (10.3 MB)
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    ---------------------- ----------------- 5.8/10.3 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.3/10.3 MB 26.7 MB/s  0:00:00
# Downloading huggingface_hub-1.4.1-py3-none-any.whl (553 kB)
#    ---------------------------------------- 0.0/553.3 kB ? eta -:--:--
#    ---------------------------------------- 553.3/553.3 kB 18.2 MB/s  0:00:00
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Installing collected packages: fsspec, huggingface-hub, transformers
#
#   Attempting uninstall: fsspec
#
#     Found existing installation: fsspec 2026.2.0
#
#     Uninstalling fsspec-2026.2.0:
#
#       Successfully uninstalled fsspec-2026.2.0
#
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#    ---------------------------------------- 0/3 [fsspec]
#   Attempting uninstall: huggingface-hub
#    ---------------------------------------- 0/3 [fsspec]
#     Found existing installation: huggingface_hub 0.36.2
#    ---------------------------------------- 0/3 [fsspec]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#     Uninstalling huggingface_hub-0.36.2:
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#       Successfully uninstalled huggingface_hub-0.36.2
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    ------------- -------------------------- 1/3 [huggingface-hub]
#   Attempting uninstall: transformers
#    ------------- -------------------------- 1/3 [huggingface-hub]
#     Found existing installation: transformers 4.56.2
#    ------------- -------------------------- 1/3 [huggingface-hub]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#     Uninstalling transformers-4.56.2:
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#       Successfully uninstalled transformers-4.56.2
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    -------------------------- ------------- 2/3 [transformers]
#    ---------------------------------------- 3/3 [transformers]
#
# Successfully installed fsspec-2025.10.0 huggingface-hub-1.4.1 transformers-5.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
os.environ["PATH"] += os.pathsep + r"C:\Users\user\Downloads\ffmpeg-8.0.1-full_build-shared\bin"

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
# from datasets import load_dataset

try:
    import torchcodec
    print("import ok")
    print(torchcodec.__version__)
except Exception as e:
    print("import failed:", repr(e))



device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3-turbo"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    torch_dtype=torch_dtype,
    device=device,
    return_timestamps=True,
    chunk_length_s=10,
    stride_length_s=2,
)

# dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
# sample = dataset[0]["audio"]
import os 

print("exists?", os.path.exists("../audio/lsy_audio_2023_58s.mp3"))

sample = "../audio/lsy_audio_2023_58s.mp3"


result = pipe(sample)
# print(result["text"])

print(result)
# Out:
# import failed: RuntimeError('Could not load libtorchcodec. Likely causes:\n          1. FFmpeg is not properly installed in your environment. We support\n             versions 4, 5, 6, 7, and 8.\n          2. The PyTorch version (2.9.0+cpu) is not compatible with\n             this version of TorchCodec. Refer to the version compatibility\n             table:\n             https://github.com/pytorch/torchcodec?tab=readme-ov-file#installing-torchcodec.\n          3. Another runtime dependency; see exceptions below.\n        The following exceptions were raised as we tried to load libtorchcodec:\n        \n[start of libtorchcodec loading traceback]\nFFmpeg version 8: Could not load this library: D:\\projects\\gpt_agent_2025_book\\venv\\Lib\\site-packages\\torchcodec\\libtorchcodec_core8.dll\nFFmpeg version 7: Could not load this library: D:\\projects\\gpt_agent_2025_book\\venv\\Lib\\site-packages\\torchcodec\\libtorchcodec_core7.dll\nFFmpeg version 6: Could not load this library: D:\\projects\\gpt_agent_2025_book\\venv\\Lib\\site-packages\\torchcodec\\libtorchcodec_core6.dll\nFFmpeg version 5: Could not load this library: D:\\projects\\gpt_agent_2025_book\\venv\\Lib\\site-packages\\torchcodec\\libtorchcodec_core5.dll\nFFmpeg version 4: Could not load this library: D:\\projects\\gpt_agent_2025_book\\venv\\Lib\\site-packages\\torchcodec\\libtorchcodec_core4.dll\n[end of libtorchcodec loading traceback].')
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/587 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Passing `generation_config` together with generation-related arguments=({'return_timestamps'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Using `chunk_length_s` is very experimental with seq2seq models. The results will not necessarily be entirely accurate and will have caveats. More information: https://github.com/huggingface/transformers/pull/20104. Ignore this warning with pipeline(..., ignore_warning=True). To use Whisper for long-form transcription, use rather the model's `generate` method directly as the model relies on it's own chunking mechanism (cf. Whisper original paper, section 3.8. Long-form Transcription).
# exists? True
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 47
#      42 print("exists?", os.path.exists("../audio/lsy_audio_2023_58s.mp3"))
#      44 sample = "../audio/lsy_audio_2023_58s.mp3"
# ---> 47 result = pipe(sample)
#      48 # print(result["text"])
#      50 print(result)
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\transformers\pipelines\automatic_speech_recognition.py:266, in AutomaticSpeechRecognitionPipeline.__call__(self, inputs, **kwargs)
#     209 def __call__(self, inputs: np.ndarray | bytes | str | dict, **kwargs: Any) -> list[dict[str, Any]]:
#     210     """
#     211     Transcribe the audio sequence(s) given as inputs to text. See the [`AutomaticSpeechRecognitionPipeline`]
#     212     documentation for more information.
#    (...)    264                 `"".join(chunk["text"] for chunk in output["chunks"])`.
#     265     """
# --> 266     return super().__call__(inputs, **kwargs)
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\transformers\pipelines\base.py:1266, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1264     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1265 elif isinstance(self, ChunkPipeline):
# -> 1266     return next(
#    1267         iter(
#    1268             self.get_iterator(
#    1269                 [inputs], num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1270             )
#    1271         )
#    1272     )
#    1273 else:
#    1274     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\transformers\pipelines\pt_utils.py:126, in PipelineIterator.__next__(self)
#     123     return self.loader_batch_item()
#     125 # We're out of items within a batch
# --> 126 item = next(self.iterator)
#     127 processed = self.infer(item, **self.params)
#     128 # We now have a batch of "inferred things".
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\transformers\pipelines\pt_utils.py:271, in PipelinePackIterator.__next__(self)
#     268             return accumulator
#     270 while not is_last:
# --> 271     processed = self.infer(next(self.iterator), **self.params)
#     272     if self.loader_batch_size is not None:
#     273         if isinstance(processed, torch.Tensor):
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torch\utils\data\dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torch\utils\data\dataloader.py:788, in _SingleProcessDataLoaderIter._next_data(self)
#     786 def _next_data(self):
#     787     index = self._next_index()  # may raise StopIteration
# --> 788     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789     if self._pin_memory:
#     790         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:33, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      31 for _ in possibly_batched_index:
#      32     try:
# ---> 33         data.append(next(self.dataset_iter))
#      34     except StopIteration:
#      35         self.ended = True
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\transformers\pipelines\pt_utils.py:188, in PipelineChunkIterator.__next__(self)
#     185     self.subiterator = self.infer(next(self.iterator), **self.params)
#     186 try:
#     187     # Try to return next item
# --> 188     processed = next(self.subiterator)
#     189 except StopIteration:
#     190     # When a preprocess iterator ends, we can start looking at the next item
#     191     # ChunkIterator will keep feeding until ALL elements of iterator
#    (...)    194     # Another way to look at it, is we're basically flattening lists of lists
#     195     # into a single list, but with generators
#     196     self.subiterator = self.infer(next(self.iterator), **self.params)
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\transformers\pipelines\automatic_speech_recognition.py:386, in AutomaticSpeechRecognitionPipeline.preprocess(self, inputs, chunk_length_s, stride_length_s)
#     383         inputs = inputs.cpu().numpy()
#     385 if is_torchcodec_available():
# --> 386     import torchcodec
#     388     if isinstance(inputs, torchcodec.decoders.AudioDecoder):
#     389         _audio_samples = inputs.get_all_samples()
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\__init__.py:12
#       9 # Note: usort wants to put Frame and FrameBatch after decoders and samplers,
#      10 # but that results in circular import.
#      11 from ._frame import AudioSamples, Frame, FrameBatch  # usort:skip # noqa
# ---> 12 from . import decoders, encoders, samplers  # noqa
#      14 try:
#      15     # Note that version.py is generated during install.
#      16     from .version import __version__  # noqa: F401
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\decoders\__init__.py:7
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates.
#       2 # All rights reserved.
#       3 #
#       4 # This source code is licensed under the BSD-style license found in the
#       5 # LICENSE file in the root directory of this source tree.
# ----> 7 from .._core import AudioStreamMetadata, VideoStreamMetadata
#       8 from ._audio_decoder import AudioDecoder  # noqa
#       9 from ._decoder_utils import set_cuda_backend  # noqa
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\_core\__init__.py:8
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates.
#       2 # All rights reserved.
#       3 #
#       4 # This source code is licensed under the BSD-style license found in the
#       5 # LICENSE file in the root directory of this source tree.
# ----> 8 from ._metadata import (
#       9     AudioStreamMetadata,
#      10     ContainerMetadata,
#      11     get_container_metadata,
#      12     get_container_metadata_from_header,
#      13     VideoStreamMetadata,
#      14 )
#      15 from .ops import (
#      16     _add_video_stream,
#      17     _get_backend_details,
#    (...)     45     seek_to_pts,
#      46 )
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\_core\_metadata.py:16
#      12 from typing import List, Optional, Union
#      14 import torch
# ---> 16 from torchcodec._core.ops import (
#      17     _get_container_json_metadata,
#      18     _get_stream_json_metadata,
#      19     create_from_file,
#      20 )
#      23 SPACES = "  "
#      26 @dataclass
#      27 class StreamMetadata:
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\_core\ops.py:85
#      65     traceback = (
#      66         "\n[start of libtorchcodec loading traceback]\n"
#      67         + "\n".join(f"FFmpeg version {v}: {str(e)}" for v, e in exceptions)
#      68         + "\n[end of libtorchcodec loading traceback]."
#      69     )
#      70     raise RuntimeError(
#      71         f"""Could not load libtorchcodec. Likely causes:
#      72           1. FFmpeg is not properly installed in your environment. We support
#    (...)     81         f"{traceback}"
#      82     )
# ---> 85 ffmpeg_major_version, core_library_path = load_torchcodec_shared_libraries()
#      88 # Note: We use disallow_in_graph because PyTorch does constant propagation of
#      89 # factory functions.
#      90 create_from_file = torch._dynamo.disallow_in_graph(
#      91     torch.ops.torchcodec_ns.create_from_file.default
#      92 )
#
# File d:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\_core\ops.py:70, in load_torchcodec_shared_libraries()
#      63         exceptions.append((ffmpeg_major_version, e))
#      65 traceback = (
#      66     "\n[start of libtorchcodec loading traceback]\n"
#      67     + "\n".join(f"FFmpeg version {v}: {str(e)}" for v, e in exceptions)
#      68     + "\n[end of libtorchcodec loading traceback]."
#      69 )
# ---> 70 raise RuntimeError(
#      71     f"""Could not load libtorchcodec. Likely causes:
#      72       1. FFmpeg is not properly installed in your environment. We support
#      73          versions 4, 5, 6, 7, and 8.
#      74       2. The PyTorch version ({torch.__version__}) is not compatible with
#      75          this version of TorchCodec. Refer to the version compatibility
#      76          table:
#      77          https://github.com/pytorch/torchcodec?tab=readme-ov-file#installing-torchcodec.
#      78       3. Another runtime dependency; see exceptions below.
#      79     The following exceptions were raised as we tried to load libtorchcodec:
#      80     """
#      81     f"{traceback}"
#      82 )
#
# RuntimeError: Could not load libtorchcodec. Likely causes:
#           1. FFmpeg is not properly installed in your environment. We support
#              versions 4, 5, 6, 7, and 8.
#           2. The PyTorch version (2.9.0+cpu) is not compatible with
#              this version of TorchCodec. Refer to the version compatibility
#              table:
#              https://github.com/pytorch/torchcodec?tab=readme-ov-file#installing-torchcodec.
#           3. Another runtime dependency; see exceptions below.
#         The following exceptions were raised as we tried to load libtorchcodec:
#
# [start of libtorchcodec loading traceback]
# FFmpeg version 8: Could not load this library: D:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\libtorchcodec_core8.dll
# FFmpeg version 7: Could not load this library: D:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\libtorchcodec_core7.dll
# FFmpeg version 6: Could not load this library: D:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\libtorchcodec_core6.dll
# FFmpeg version 5: Could not load this library: D:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\libtorchcodec_core5.dll
# FFmpeg version 4: Could not load this library: D:\projects\gpt_agent_2025_book\venv\Lib\site-packages\torchcodec\libtorchcodec_core4.dll
# [end of libtorchcodec loading traceback].
