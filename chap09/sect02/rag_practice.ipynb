# %%
# %pip install pymupdf pypdf langchain_community
# Out:
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 20.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 25.1 MB/s  0:00:00
# ...
#
#    ----------------------------------------  0/10 [pypdf]
#    ----------------------------------------  0/10 [pypdf]
#    ----------------------------------------  0/10 [pypdf]
#    ----------------------------------------  0/10 [pypdf]
#    ----------------------------------------  0/10 [pypdf]
#    ----------------------------------------  0/10 [pypdf]
#    ----------------------------------------  0/10 [pypdf]
#    ----------------------------------------  0/10 [pypdf]
#    ----------------------------------------  0/10 [pypdf]
#    ----------------------------------------  0/10 [pypdf]
#    ---- -----------------------------------  1/10 [mypy-extensions]
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("D:\projects\gpt_agent_2025_book\chap09\data\OneNYC_2050_Strategic_Plan.pdf")

data_nyc = loader.load()

print(data_nyc)
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign 14.0 (Windows)', 'creationdate': '2019-04-30T10:57:03-04:00', 'moddate': '2020-01-03T16:36:59-05:00', 'trapped': '/False', 'source': 'D:\\projects\\gpt_agent_2025_book\\chap09\\data\\OneNYC_2050_Strategic_Plan.pdf', 'total_pages': 60, 'page': 0, 'page_label': '1'}, page_content='OneNYC \n2050\nBUILDING A STRONG \nAND FAIR CITY \nVOLUME 1 OF 9  \nA\nPRIL 2019\nTHE CITY OF NEW YORK\nMAYOR BILL DE BLASIO\nDEAN FULEIHAN  \nFIRST DEPUTY MAYOR \nD\nOMINIC WILLIAMS  \nCHIEF POLICY ADVISOR\nD\nANIEL A. ZARRILLI  \nOne NYC DIRECTOR'), Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign 14.0 (Windows)', 'creationdate': '2019-04-30T10:57:03-04:00', 'moddate': '2020-01-03T16:36:59-05:00', 'trapped': '/False', 'source': 'D:\\projects\\gpt_agent_2025_book\\chap09\\data\\OneNYC_2050_Strategic_Plan.pdf', 'total_pages': 60, 'page': 1, 'page_label': '2'}, page_content='2   |   O neNYC 2
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 텍스트 데이터를 1000자 단위로 나눔. overlap은 100자로 설정 
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
all_splits = text_splitter.split_documents(data_nyc)

# %%
for i, split in enumerate(all_splits):
    print(f"Split {i+1}:------------------------------\n")
    print(split)
# Out:
# Split 1:------------------------------
#
# page_content='OneNYC
# 2050
# BUILDING A STRONG
# AND FAIR CITY
# VOLUME 1 OF 9
# A
# PRIL 2019
# THE CITY OF NEW YORK
# MAYOR BILL DE BLASIO
# DEAN FULEIHAN
# FIRST DEPUTY MAYOR
# D
# OMINIC WILLIAMS
# CHIEF POLICY ADVISOR
# D
# ANIEL A. ZARRILLI
# One NYC DIRECTOR' metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign 14.0 (Windows)', 'creationdate': '2019-04-30T10:57:03-04:00', 'moddate': '2020-01-03T16:36:59-05:00', 'trapped': '/False', 'source': 'D:\\projects\\gpt_agent_2025_book\\chap09\\data\\OneNYC_2050_Strategic_Plan.pdf', 'total_pages': 60, 'page': 0, 'page_label': '1'}
# Split 2:------------------------------
#
# page_content='2   |   O neNYC 2050
# NYC.GOV/O neNYC
# ONENYC 2050 IS A STRATEGY TO SECURE OUR CITY’S
# FUTURE AGAINST THE CHALLENGES OF TODAY AND
# TOMORROW. WITH BOLD ACTIONS TO CONFRONT OUR
# CLIMATE CRISIS, ACHIEVE EQUITY, AND STRENGTHEN
# OUR DEMOCRACY, WE ARE BUILDING A STRONG AND
# ...

# %%
print(type(all_splits[0]))
# Out:
# <class 'langchain_core.documents.base.Document'>

# %%
loader_seoul = PyPDFLoader(r'D:\projects\gpt_agent_2025_book\chap09\data\2040_seoul_plan.pdf')
data_seoul = loader_seoul.load()
seoul_splits = text_splitter.split_documents(data_seoul)
for i, split in enumerate(seoul_splits):
    print(f'Split {i+1}:---------------------------')
    print(split)
# Out:
# Split 1:---------------------------
# page_content='2040 서울도시기본계획은 2019년 3월에 시작하여 2022년 12월까지 3년 9개월 동안 시민, 공무원,
# 전문가 등 수 많은 주체가 참여한 서울시 장기 종합발전계획이다.
# 이번 자료집에는 도시기본계획의 위상, 미래상, 부문별 전략계획, 생활권계획 등 사전기획 단계부터
# 계획완료 시점까지 논의되었던 내용을 정리하였다.
# 자료집의 의미는 첫째, 미래 여건변화에 대한 시민 설문조사와 2040 서울플랜 시민계획단의 논의
# 결과를 토대로 도시기본계획이 수립되는 과정을 정리하고 둘째, 다양한 분야의 전문가 의견과 서울시
# 및 자치구의 제안내용이 어떻게 직·간접적으로 2040 서울도시기본계획에 반영되었는지를 모니터링
# 하며 셋째, 관련기관과의 협의과정에서 계획내용이 어떻게 수정 보완되었는지 등 계획과정을 투명하게
# 공개하여 시민의 이해를 돕기 위함이다.
# 자료집의 일부 내용은 계획의 위계와 성격, 계획 간 정합성 등을 고려하여 반영되지 못한 부분도
# 있으나 참고사항으로 남겨 두었다.' metadata={'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creator': 'PScript5.dll Version 5.2.2', 'creationdate': '2023-02-14T11:05:36+09:00', 'author': '', 'moddate': '2023-02-14T18:21:42+09:00', 'title': '', 'source': 'D:\\projects\\gpt_agent_2025_book\\chap09\\data\\2040_seoul_plan.pdf', 'total_pages': 272, 'page': 3, 'page_label': '4'}
# Split 2:---------------------------
# page_content='목차
# 1. 사전기획
#  1
# 1.1 사전자문단 회의
# ...

# %%
print(seoul_splits[50].page_content)
print('--------------------------')
print(seoul_splits[51].page_content)
# Out:
# 20 1. 사전기획
# ❚ 실현방안 (거버넌스)
# 목표달성을 위한 모니터링 담당 부서 설정 필요
#  목표 달성을 위해 구체적으로 어디에서 수행되어야 하는지에 대한 언급이 있으면 모니터링에 용이할
# 것임. 예를 들어 부담 가능한 주택 전략을 채택할 경우, 주택뿐 아니라 교통, 재생에서도 역세권이나
# 주요 교차점에 대한 논의를 통해 여러 부문에 걸쳐 있는 각 전략에 대해 논의할 필요가 있음
# 부문별 상충을 완화하거나 보완할 방향에 대한 검토 필요
#  해당 전략을 위해 각 국에서 무엇을 할 수 있는지 수렴하는 과정에 대한 피드백이 필요. 구체성을
# 높이는 쪽으로 이슈별 접근을 했지만, 사실상 각 부문이 모두 참여해야 하는데 이러다 보면 부문별
# 상충이 일어날 것이고 이를 완화하거나 보완할 방향을 검토해야 함
#  공간 관련 법 체계와 정합성 등을 보면, 재생이나 역세권 또는 경관축 설정과 밀접하게 관련된 연계
# 방향이 발생할 수 있음
#  도시철도나 도로 등은 선적인 형태이지만 상당히 직접적으로 물리적 연계성을 가질 수 있고, 산업이나
# 공업, 전통 및 도심형 제조업 등이 공간계획과 밀접한 관련이 있으므로 상충하는 부분을 확인하고
# 조정해야 정합성 달성이 가능함
#  이를 함께 연계해서 검토하고 서울시 모든 실국이 어떤 것을 할 수 있을지 체크하는 방향으로 접근
# 해야 할 것임
# 최상위계획으로서 포괄적인 이야기를 담고, 주무부서를 지정해서 분담하는 방향 검토
#  도시기본계획이 최상위계획이라면 최상위에서 해결할 만한 종합적이고 포괄적인 이야기를 담아야
# 할 것이므로 실국에서 알아서 할 일이 있고 기본계획에서는 모든 것을 언급할 수는 없음
#  기본계획은 앞으로 5~10년 동안 우리가 핵심적으로 대응해야 할 이슈가 무엇인지 적어놓고 해결하기
# 위해서 부문별 계획이 과 단위 정도에서 서울시 내 실국이 무엇을 해야 할지 나타낼 수 있을 것임
# ...

# %%
for i in range(len(seoul_splits) - 1):
    seoul_splits[i].page_content += '\n' + seoul_splits[i+1].page_content[:100]

print(seoul_splits[50].page_content)
print('--------------------------')
print(seoul_splits[51].page_content)
# Out:
# 20 1. 사전기획
# ❚ 실현방안 (거버넌스)
# 목표달성을 위한 모니터링 담당 부서 설정 필요
#  목표 달성을 위해 구체적으로 어디에서 수행되어야 하는지에 대한 언급이 있으면 모니터링에 용이할
# 것임. 예를 들어 부담 가능한 주택 전략을 채택할 경우, 주택뿐 아니라 교통, 재생에서도 역세권이나
# 주요 교차점에 대한 논의를 통해 여러 부문에 걸쳐 있는 각 전략에 대해 논의할 필요가 있음
# 부문별 상충을 완화하거나 보완할 방향에 대한 검토 필요
#  해당 전략을 위해 각 국에서 무엇을 할 수 있는지 수렴하는 과정에 대한 피드백이 필요. 구체성을
# 높이는 쪽으로 이슈별 접근을 했지만, 사실상 각 부문이 모두 참여해야 하는데 이러다 보면 부문별
# 상충이 일어날 것이고 이를 완화하거나 보완할 방향을 검토해야 함
#  공간 관련 법 체계와 정합성 등을 보면, 재생이나 역세권 또는 경관축 설정과 밀접하게 관련된 연계
# 방향이 발생할 수 있음
#  도시철도나 도로 등은 선적인 형태이지만 상당히 직접적으로 물리적 연계성을 가질 수 있고, 산업이나
# 공업, 전통 및 도심형 제조업 등이 공간계획과 밀접한 관련이 있으므로 상충하는 부분을 확인하고
# 조정해야 정합성 달성이 가능함
#  이를 함께 연계해서 검토하고 서울시 모든 실국이 어떤 것을 할 수 있을지 체크하는 방향으로 접근
# 해야 할 것임
# 최상위계획으로서 포괄적인 이야기를 담고, 주무부서를 지정해서 분담하는 방향 검토
#  도시기본계획이 최상위계획이라면 최상위에서 해결할 만한 종합적이고 포괄적인 이야기를 담아야
# 할 것이므로 실국에서 알아서 할 일이 있고 기본계획에서는 모든 것을 언급할 수는 없음
#  기본계획은 앞으로 5~10년 동안 우리가 핵심적으로 대응해야 할 이슈가 무엇인지 적어놓고 해결하기
# 위해서 부문별 계획이 과 단위 정도에서 서울시 내 실국이 무엇을 해야 할지 나타낼 수 있을 것임
# ...

# %%
print(len(all_splits))
all_splits.extend(seoul_splits)
print(len(all_splits))
# Out:
# 176
# 537

# %%
# %pip install langchain_chroma
# Out:
# ...
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    --- ------------------------------------ 2.1/21.7 MB 11.8 MB/s eta 0:00:02
#    ------------- -------------------------- 7.1/21.7 MB 16.8 MB/s eta 0:00:01
#    --------------- ------------------------ 8.7/21.7 MB 15.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 9.2/21.7 MB 11.7 MB/s eta 0:00:02
#    -------------------------- ------------- 14.4/21.7 MB 13.9 MB/s eta 0:00:01
#    -------------------------------- ------- 17.8/21.7 MB 15.4 MB/s eta 0:00:01
#    -------------------------------------- - 21.0/21.7 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------- 21.7/21.7 MB 13.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 11.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
# ...

# %%
from langchain_openai import OpenAIEmbeddings

from dotenv import load_dotenv
import os 

load_dotenv()

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
embedding = OpenAIEmbeddings(model='text-embedding-3-large', api_key=OPENAI_API_KEY)
v = embedding.embed_query('뉴욕의 온실가스 저감 정책은 뭐야?')
print(v)
print(len(v))
# Out:
# [-0.006772136781364679, -0.04893183335661888, -0.012226970866322517, 0.007730175741016865, -0.04093220829963684, -0.009676191955804825, 0.006269166711717844, 0.026274215430021286, -0.05034494027495384, -0.014119097031652927, -0.0002552275254856795, -0.019124850630760193, 0.025435931980609894, -0.0008031059987843037, 0.002728913677856326, -0.018059032037854195, -0.0391358882188797, -0.043399158865213394, 0.07443961501121521, -0.011424613185226917, 0.04871627315878868, -0.013771808706223965, -0.0191368255764246, 0.005655422806739807, -0.032621223479509354, 0.01638246327638626, 0.02367553487420082, 0.021005000919103622, -0.004874022677540779, 0.03731561079621315, 0.0357108972966671, 0.03077699802815914, 0.017520135268568993, -0.008861859329044819, -0.01676568016409874, 0.014454411342740059, 0.0622246228158474, -0.02974710613489151, 0.048428863286972046, -0.0025133551098406315, -0.027399910613894463, 0.01268203929066658, -0.03154342994093895, -0.00668830843642354, 0.019196704030036926, -
# ...

# %%
from langchain_chroma import Chroma
import os 

# 크로마DB를 생성하고 저장할 위치 지정 
# 크로마DB가 생성되면 sqlite3 파일이 저장 
persist_directory = '../chroma_store'

if not os.path.exists(persist_directory):
    print('Creating new Chroma store')
    vectorStore = Chroma.from_documents(
        documents = all_splits,
        embedding=embedding,
        persist_directory=persist_directory
    )
else:
    print('Loading existing Chroma store')
    vectorStore = Chroma(
        persist_directory=persist_directory,
        embedding_function=embedding
    )
# Out:
# Creating new Chroma store

# %%
retriever = vectorStore.as_retriever(k=3)
docs = retriever.invoke('서울시의 환경 정책이 궁금해.')

for d in docs:
    print(d)
    print('--------')
# Out:
# page_content='38 1. 사전기획
#  30년 이상 경과된 노후주택은 서울 주택호수의 18.3%, 1990년대 건축된 주택은 26.6%로 10년 내
# 노후주택이 크게 증가할 것으로 예상됨. 특히, 노원구(노후주택의 비율, 33.9%), 양천구(29.7%),
# 용산구(28.8%), 종로구(26.7%), 영등포구(25.6%)는 노후주택의 비율이 높게 나타나고 있음
#  1980년대 대규모 택지개발사업을 통해 조성된 아파트단지가 밀집한 상계 8·9·10동, 반포본동,
# 오륜동, 잠실7동은 모든 주택의 건축연한이 30년을 초과하여 주거환경의 개선을 위한 특수해가
# 필요한 상황임. 건축물의 구조·안전에 대한 지속적인 모니터링은 물론이고, 지역 특성을 반영하여
# 노후주택에 대한 개·보수, 소규모 정비, 정비사업 등 다양한 방식을 통해 환경을 개선할 필요가 있음
# 6. 기후·환경
# 증가하는 생활폐기물 배출량과 우려되는 대기오염
#  서울에서 발생하는 폐기물을 처리해왔던 인천 수도권매립지의 매립 종료가 2025년에 예정되면서
# 폐기물 처리가 주요한 이슈로 대두되고 있음. 반면, 서울의 2019년 폐기물 배출량은 2015년보다
# 0.6만 톤 증가(연평균 3.4%)한 4.8만 톤이 배출된 것으로 나타남. 이 중 생활폐기물은 9,847톤으로
# 2015년에 비해 409톤 증가(연평균 1.1%)해, 주민 1인당 생활폐기물 발생량은 0.98㎏까지 증가하
# 였음. 이후 코로나19로 인한 온라인 쇼핑, 배달 음식 소비증가 등을 고려하면 폐기물 배출량은 더욱
# 증가할 것으로 예상됨
# [그림 1-17] 폐기물 발생량 및 1인당 생활폐기물 배출량(2010~2019)
# 자료: 환경부, 서울시 폐기물 재활 용 현황 통계, 각  년 도
#  한편, 2020년 코로나19로 활동이 주춤하면서 미세먼지와 관련한 대기질 지표는 일시적으로 좋아지는
# 양상을 보임. 미세먼지의 연평균 농도는 국가환경 기준(50㎍/㎥/년)을 밑돌지만, 단기간 고농도
# ...

# %%
# %pip install langchain-classic
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_openai import ChatOpenAI

chat = ChatOpenAI(model="gpt-4o-mini")

question_answering_prompt = ChatPromptTemplate.from_messages(
    [
        ('system', "사용자의 질문에 대해 아래 context에 기반하여 답변하라:\n\n{context}"),
        MessagesPlaceholder(variable_name="messages"), # 동적 데이터를 프롬프트에 삽입하기 위해 사용하는 클래스
    ]
)

document_chain = create_stuff_documents_chain(chat, question_answering_prompt) # 여러 텍스트를 결합해 답변으 새성 체인을 만드는 함수

# %%
from langchain_classic.memory import ChatMessageHistory

# 채팅 메시지를 저장할 메모리 객체 생성 
chat_history = ChatMessageHistory()

# 사용자 질문을 메모리에 저장 
chat_history.add_user_message('서울시의 온실가스 저감 정책에 대해 알려줘.')

# 문서 검색하고 답변 생성 
answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

# 생성된 답변 메모리에 저장 
chat_history.add_ai_message(answer)

print(answer)
# Out:
# 서울시의 온실가스 저감 정책은 기후변화 대응을 위한 중요한 전략 중 하나로, 여러 가지 접근 방식을 포함하고 있습니다. 주요 내용은 다음과 같습니다:
#
# 1. **기후변화 대응 종합계획**: 서울시는 기후변화 대응을 위한 종합계획을 수립하여 장기적인 정책 목표를 설정하고 있습니다. 이 계획은 기후변화에 효과적으로 대응하기 위한 다양한 방안을 모색하고 있습니다.
#
# 2. **에너지 효율화**: 기후변화 대응과 관련된 정책으로, 에너지 소비를 줄이고 효율성을 높이기 위한 다양한 프로그램이 시행되고 있습니다. 이는 지속가능한 도시 발전을 도모하는 데 중요한 요소입니다.
#
# 3. **재활용 및 자원순환**: 폐기물 감소와 자원순환을 위해 '자원순환 자립 도시'를 목표로 하고 있으며, 생활폐기물의 매립을 최소화하는 방향으로 정책을 추진하고 있습니다.
#
# 4. **온실가스 감축을 위한 공간적인 계획**: 도시기본계획에서 온실가스 감축과 대기질 관리를 위한 공간적인 계획을 마련하고 있습니다. 이는 개발 시 고밀 개발을 제한하고 녹지 및 친환경 인프라를 적극적으로 도입하는 등의 방식으로 실행됩니다.
#
# 5. **시설 및 주민 수용성**: 재활용 시설의 지하화와 같은 보다 효율적인 자원 관리 방법에 대한 논의가 이루어지고 있지만, 주민들의 수용성을 고려한 접근이 필요합니다.
#
# 6. **협력체계 구축**: 수도권과 충남권 등과 협력하여 미세먼지와 같은 대기질 문제에 공동으로 대응하고 있으며, 이러한 협력체계는 온실가스 저감에도 기여하고 있습니다.
#
# 서울시는 이와 같은 다양한 정책과 계획을 통해 온실가스를 저감하고 지속 가능한 환경을 만들어 가기 위해 노력하고 있습니다.

# %%
for m in chat_history.messages:
    print(m)
# Out:
# content='서울시의 온실가스 저감 정책에 대해 알려줘.' additional_kwargs={} response_metadata={}
# ...

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
query_for_nyc = "뉴욕은?"

# query_argumentation
# 기존 대화 내용을 활용해 query_argumentation 수행 
query_argumentation_prompt = ChatPromptTemplate.from_messages(
    [
        MessagesPlaceholder(variable_name='messages'), # 기존 대화 내용
        (
            "system",
            "기존의 대화 내용을 활용하여 사용자가 질문한 의도를 파악해서 한 문장의 명료한 질문으로 변환하라. 대명사나 이, 저, 그와 같은 표현을 명확한 명사로 표현하라. :\n\n{query}",
        )
    ]
)

# %%
query_argumentation_chain = query_argumentation_prompt | chat | StrOutputParser()

# %%
argumented_query = query_argumentation_chain.invoke({
    'messages': chat_history.messages,
    "query": query_for_nyc
})

print(argumented_query)
# Out:
# 뉴욕시는 어떤 온실가스 저감 정책을 시행하고 있나요?

# %%
docs = retriever.invoke(argumented_query)

for d in docs:
    print(d)
    print('--------')
# Out:
# page_content='New York City, because of its density and public transportation
# system, has long had a smaller per capita carbon footprint than
# any other big city in the United States — and we have made
# significant progress reducing GHG emissions over the last decade,
# using new technologies and innovations to get us there. The City
# has assumed a leading global role in fighting climate change,
# and the actions we take can become a national and global model.
# However, the lack of commitment by the federal government
# to the Paris Agreement has placed New York and the world in a
# precarious position. Time is running out.
# While New York City has made strides to achieve a reduction in
# greenhouse gas emissions, global emissions continue to rise,
# putting New Yorkers at risk.
# CHANGE IN GHG EMISSIONS, 2005-2017
# Source: Mayor’s Office, International Energy Agency
# 0%
# 5%
# GLOBAL
# NEW YORK CITY-5%
# 15%
# -15%
# -20%
# ...

# %%
chat_history.add_user_message(query_for_nyc)

answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)


# 생성된 답변 메모리에 저장 
chat_history.add_ai_message(answer)

print(answer)
# Out:
# 뉴욕시는 온실가스 저감을 위한 다양한 정책과 계획을 추진하고 있습니다. 주요 내용은 다음과 같습니다:
#
# 1. **OneNYC 계획**: 뉴욕시는 OneNYC라는 장기 전략 계획을 통해 2050년까지 탄소 중립을 목표로 설정하고 있습니다. 이 계획은 경제, 환경, 사회적 불평등 등을 종합적으로 고려하여 뉴욕시의 발전 방향을 제시하고 있습니다.
#
# 2. **온실가스 배출 감축**: 뉴욕시는 2005년 대비 2017년까지 온실가스를 17% 저감하는 성과를 올렸습니다. 이는 도시 밀도가 높고 대중교통이 발달한 특성을 활용한 결과입니다.
#
# 3. **시설 에너지 효율성**: 건물에서의 온실가스 배출을 줄이기 위해 에너지 효율성을 높이고 100% 청정 전력을 공급받는 것을 목표로 하는 정책을 추진하고 있습니다.
#
# 4. **기후 이니셔티브**: 뉴욕시는 기후변화 대응을 위해 불필요한 일회용 플라스틱 사용을 줄이는 정책을 포함한 여러 이니셔티브를 통해 선도적인 역할을 하고 있습니다.
#
# 5. **일자리 창출**: 뉴욕시는 기후 해결책에 대한 투자와 함께 10년 동안 100,000개의 좋은 일자리를 창출하는 것을 목표로 하고 있습니다.
#
# 6. **친환경 교통체계**: 도시 전역에 걸쳐 페리 네트워크를 구축하여 교통 편의를 개선하고, 건강과 안전을 위한 조치를 강화하고 있습니다.
#
# 7. **장기적 비전**: OneNYC 2050 계획은 불평등, 경제, 지역 사회, 건강, 교육, 환경, 교통, 인프라 등 다양한 목표를 설정해 시민의 삶의 질을 향상시키고자 합니다.
#
# 뉴욕시는 이러한 다양한 정책을 통해 기후 변화에 효과적으로 대응하고, 지속 가능한 도시로 발전하고자 노력하고 있습니다.
